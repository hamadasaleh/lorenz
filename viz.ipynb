# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("./lorenz.csv")
df.head()
# Out:
#           x         y         z
# 0  1.000000  1.260000  0.983333
# 1  1.026000  1.517567  0.969711
# 2  1.075157  1.779722  0.959422
# 3  1.145613  2.052653  0.952973
# 4  1.236317  2.341981  0.951075

# %%
df.shape
# Out:
# (9999, 3)

# %%
fig = px.line_3d(df, x="x", y="y", z="z", title="Lorenz Oscillator (The Butterfly Effect)")
fig.show()
